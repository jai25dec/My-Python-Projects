# %% [markdown]
# ## Project Description
# - This project performs **Exploratory Data Analysis (EDA)** on the Big Basket product dataset.
# - The dataset contains **27,555 entries** with details such as:
#   - Product name, category, sub-category, and brand
#   - Sale price, market price, discount
#   - Product type, rating, and description
# - Key steps in the analysis include:
#   - Importing and cleaning the dataset
#   - Handling missing values and outliers
#   - Identifying top-selling and least-selling products
#   - Measuring discounts and analyzing pricing trends
#   - Exploring product category distribution
#   - Visualizing discount and rating distributions
# - The goal is to uncover insights into **customer preferences, pricing strategies, and product performance** on Big Basket.

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"D:\Projects Datasets\BigBasket Products.csv")
data.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %%
# Step 3: Get Description of the Data
data.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
# Step 4: Information about the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
# Step 5: Top & Least Sold Products
top_products = data['product'].value_counts().head(10)
least_products = data['product'].value_counts().tail(10)
print('Top 10 Sold Products:\n', top_products)
print('\nLeast 10 Sold Products:\n', least_products)
# Out:
# Top 10 Sold Products:
#  product
# Turmeric Powder/Arisina Pudi          26
# Extra Virgin Olive Oil                15
# Cow Ghee/Tuppa                        14
# Soft Drink                            12
# Colorsilk Hair Colour With Keratin    12
# Olive Oil - Extra Virgin              12
# Coriander Powder                      11
# Powder - Coriander                    11
# Ghee/Tuppa                            11
# Peanut Butter - Creamy                10
# Name: count, dtype: int64
#
# Least 10 Sold Products:
#  product
# 50-50 Maska Chaska                                               1
# Opalware Classique Serving Bowl - Medium, Royal Irish            1
# Powder - Pepper                                                  1
# Mixture - Bajra Puffs Masala                                     1
# Sauteed Onion & Garlic Pasta Sauce                               1
# Pepper & Herb Salami Chicken                                     1
# ...

# %%
# Step 6: Measuring Discount
data['discount'] = data['market_price'] - data['sale_price']
data[['product', 'market_price', 'sale_price', 'discount']].head(10)
# Out:
#                                              product  market_price  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg         220.0
# 1                              Water Bottle - Orange         180.0
# 2                     Brass Angle Deep - Plain, No.2         250.0
# 3  Cereal Flip Lid Container/Storage Jar - Assort...         176.0
# 4                 Creme Soft Soap - For Hands & Body         162.0
# 5                  Germ - Removal Multipurpose Wipes         199.0
# 6                                       Multani Mati          58.0
# 7                  Hand Sanitizer - 70% Alcohol Base         250.0
# 8  Biotin & Collagen Volumizing Hair Shampoo + Bi...        1098.0
# 9               Scrub Pad - Anti- Bacterial, Regular          20.0
#
#    sale_price  discount
# 0       220.0       0.0
# 1       180.0       0.0
# 2       119.0     131.0
# 3       149.0      27.0
# 4       162.0       0.0
# 5       169.0      30.0
# 6        58.0       0.0
# 7       250.0       0.0
# ...

# %%
# Step 7: Find Missing Values
data.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
# Step 8: Handle Outliers (with Mean)
Q1 = data['sale_price'].quantile(0.25)
Q3 = data['sale_price'].quantile(0.75)
IQR = Q3 - Q1
filtered_data = data[~((data['sale_price'] < (Q1 - 1.5 * IQR)) | (data['sale_price'] > (Q3 + 1.5 * IQR)))]
data['sale_price'] = data['sale_price'].fillna(data['sale_price'].mean())
print('Original rows:', len(data))
print('Rows after removing outliers:', len(filtered_data))
print('Missing sale_price values after filling:', 
data['sale_price'].isnull().sum())
# Out:
# Original rows: 27555
# Rows after removing outliers: 25350
# Missing sale_price values after filling: 0

# %%
# Step 9(a): Product Category Distribution
plt.figure(figsize=(10,6))
data['category'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
# Step 9(b): Discounts Comparison
plt.figure(figsize=(10,6))
sns.histplot(data['discount'], bins=20, kde=True, color='green')
plt.title('Discount Distribution')
plt.xlabel('Discount')
plt.ylabel('Number of Products')
plt.show()

# %%
# Step 9(c): Ratings Distribution
plt.figure(figsize=(8,5))
sns.boxplot(x=data['rating'])
plt.title('Product Ratings Boxplot')
plt.show()

# %% [markdown]
# ## Project Conclusion
# - The dataset highlights diverse product categories, with **Beauty & Hygiene** and **Cleaning & Household** being the most common.
# - **Top-selling products** include staples like Turmeric Powder and Olive Oil, while niche items show minimal sales.
# - Discount analysis reveals that most products have **low to moderate discounts**, with only a few high-discount items.
# - Ratings are concentrated between **3.5 and 4.5**, indicating generally positive customer satisfaction.
# - Outliers were removed and missing values (e.g., sale_price) were handled using the mean, ensuring data consistency.
# - Overall, the EDA provides valuable insights into:
#   - Popular product categories
#   - Pricing and discount trends
#   - Customer satisfaction levels
# - These findings can help Big Basket optimize **inventory management, pricing strategies, and marketing focus**.
